# %% [markdown]
# <a href="https://colab.research.google.com/github/Artrazr/expertiza_med/blob/main/Kahaton_v0_0_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Решение:**
# Производим загрузку имеющихся данных из действующих источников в формате csv

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/0- Методички/MKB10_i21.csv')
data # данные из Приказ Минздрава России от 10.05.2017 N 203н
# Out:
#                                            NLP_poced  ... 3.9.3. Критерии качества специализированной медицинской помощи взрослым при остром коронарном синдроме (коды по МКБ-10: I20 I21 I24)
# 0                                 осмотр кардиологом  ...  Выполнен осмотр врачом-кардиологом не позднее ...
# 1              электрокардиографическое исследование  ...  Выполнено электрокардиографическое исследовани...
# 2                     определение уровня тропонинов   ...  Выполнено определение уровня тропонинов I  T в...
# 3  терапия фибринолитическими лекарственными преп...  ...  Проведена (при остром коронарном синдроме с по...
# 4                     терапия ингибиторами агрегации  ...  Проведена терапия ингибиторами агрегации тромб...
# 5                         терапия ацетилсалициловой   ...       Проведена терапия ацетилсалициловой кислотой
# 6            терапия гиполипидемическими препаратами  ...  Проведена терапия гиполипидемическими препаратами
# ...

# %%
data1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/0- Методички/MKB10_Card.csv')
data1 # данные из карты клиента о проведенных процедурах
# Out:
#              Data                                          Procedure       ID
# 0  01.02.20 14:32                      поступил в приемное отделение  0.0.0.1
# 1  01.02.20 14:34                 Выполнен осмотр врачом-кардиологом  3.9.3.1
# 2  02.02.20 14:41    Выполнено электрокардиографическое исследование  3.9.3.2
# 3  03.02.20 18:10                      Определение уровня тропонинов  3.9.3.3
# 4  04.02.20 16:10  Проведена терапия ингибиторами агрегации тромб...  3.9.3.5
# 5  05.02.20 15:10  Проведена терапия гиполипидемическими препаратами  3.9.3.7

# %%
BD = data.merge(data1, left_on='ID', right_on='ID', how='left')
BD
# Out:
#                                            NLP_poced  ...                                          Procedure
# 0                                 осмотр кардиологом  ...                 Выполнен осмотр врачом-кардиологом
# 1              электрокардиографическое исследование  ...    Выполнено электрокардиографическое исследование
# 2                     определение уровня тропонинов   ...                      Определение уровня тропонинов
# 3  терапия фибринолитическими лекарственными преп...  ...                                                NaN
# 4                     терапия ингибиторами агрегации  ...  Проведена терапия ингибиторами агрегации тромб...
# 5                         терапия ацетилсалициловой   ...                                                NaN
# 6            терапия гиполипидемическими препаратами  ...  Проведена терапия гиполипидемическими препаратами
# 7  электрокардиографическое исследование до начал...  ...                                                NaN
# ...
